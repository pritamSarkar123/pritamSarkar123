# %%
import pandas as pd

# %%
df=pd.DataFrame([
    [1,2,3],
    [4,5,6]
])
df
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6

# %%
df=pd.DataFrame([
    [1,2,3],
    [4,5,6]
],columns=["quantity","price","ID"])
df
# Out:
#    quantity  price  ID
# 0         1      2   3
# 1         4      5   6

# %%
df=pd.DataFrame([
    [1,2,3],
    [4,5,6]
],columns=["quantity","price","ID"],index=["one","two"])
df
# Out:
#      quantity  price  ID
# one         1      2   3
# two         4      5   6

# %%
df=pd.DataFrame([
    {"name":"pritam","age":26},
    {"name":"eshani","age":26}
])
df
# Out:
#      name  age
# 0  pritam   26
# 1  eshani   26

# %%
df=pd.DataFrame({
    "name":["pritam","eshani"],
    "age":[26,26]
})
df
# Out:
#      name  age
# 0  pritam   26
# 1  eshani   26

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#dir(df)
#help(df.mean)

# %%
#df.mean().mean()
#type(df.mean())
#type(df.mean().mean())
# Out:
# float

# %%
df=pd.read_csv('C:\\Users\\pritam\\anaconda3\\pritamSarkar123\\DAML\\Moc Data Creation\\May_data.csv')
df.head()
# Out:
#    Order ID                   Product  Quantity Ordered  Price Each  \
# 0  143253.0    AAA Batteries (4-pack)               1.0        2.99
# 1  143254.0     AA Batteries (4-pack)               1.0        3.84
# 2  143255.0    AAA Batteries (4-pack)               3.0        2.99
# 3  143256.0     AA Batteries (4-pack)               3.0        3.84
# 4  143257.0  Lightning Charging Cable               1.0       14.95
#
#        Order Date                   Purchase Address
# 0  05/19/19 13:15    449 Hill St, Portland, OR 97035
# 1  05/28/19 21:20  430 Elm St, Los Angeles, CA 90001
# 2  05/23/19 15:21     346 14th St, Seattle, WA 98101
# 3  05/15/19 21:23    668 Sunset St, Dallas, TX 75001
# 4  05/18/19 11:03   189 Spruce St, Seattle, WA 98101

# %%
from bs4 import BeautifulSoup
import requests

# %%
r=requests.get('https://en.wikipedia.org/wiki/Foot')
r.content[:300]
# Out:
# b'\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Foot - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"'

# %%
soup=BeautifulSoup(r.content)
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Foot - Wikipedia\n  </title>\n  <script>\n   document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"1b045a1c-7392-41c6-b52e-ae5f8b41b94f","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"Foot","wgTitle":"Foot","wgCurRevisionId":965464525,"wgRevisionId":965464525,"wgArticleId":11492,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["CS1 maint: archived copy as title","Wikipedia indefinitely move-protected pages","Wikipedia indefinitely semi-protected pages","Articles with short description","All art
# ...
