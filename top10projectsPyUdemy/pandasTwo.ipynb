# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', 'multipleFiles', 'pandasOne.ipynb', 'pandasTwo.ipynb']

# %%
os.listdir(path='multipleFiles')
# Out:
# ['data.txt',
#  'supermarkets-commas.txt',
#  'supermarkets-semi-colons.txt',
#  'supermarkets.csv',
#  'supermarkets.json',
#  'supermarkets.xlsx']

# %%
import pandas as pd

# %%
df1=pd.read_csv('multipleFiles\\supermarkets.csv')
df1=df1.set_index('ID')
df1.head()
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12

# %%
df2=pd.read_json('multipleFiles/supermarkets.json')
df2=df2.set_index('ID')
df2.head()
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12

# %%
df3=pd.read_excel('multipleFiles/supermarkets.xlsx',sheet_name=0)
df3=df3.set_index('ID')
df3.head()
# Out:
#             Address           City             State Country Supermarket Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA          Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA      Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA      Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA       Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA          Sanchez
#
#     Number of Employees
# ID
# 1                     8
# 2                    15
# 3                    25
# 4                    10
# 5                    12

# %%
df4=pd.read_csv('multipleFiles/supermarkets-commas.txt',sep=',')
df4=df4.set_index('ID')
df4.head()
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12

# %%
df5=pd.read_csv('multipleFiles/supermarkets-semi-colons.txt',sep=';')
df5=df5.set_index('ID')
df5.head()
# Out:
#             Address           City             State Country          Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA       Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA   Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA   Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA    Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA       Sanchez
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12

# %%
df6=pd.read_csv('multipleFiles/data.txt',header=None)

df6.columns=['ID','Address', 'City', 'State', 'Country', 'Name', 'Employees']
df6=df6.set_index('ID')

df6.head()
# Out:
#             Address           City             State Country         Name  \
# ID
# 1      3666 21st St  San Francisco          CA 94114     USA      Madeira
# 2    735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 3       332 Hill St  San Francisco  California 94114     USA  Super River
# 4      3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 5   1056 Sanchez St  San Francisco        California     USA      Sanchez
#
#     Employees
# ID
# 1           8
# 2          15
# 3          25
# 4          10
# 5          12

# %%
df7=pd.read_json('multipleFiles/supermarkets.json')
df7=df7.set_index('Address')
df7.head()
# Out:
#                  ID           City             State Country         Name  \
# Address
# 3666 21st St      1  San Francisco          CA 94114     USA      Madeira
# 735 Dolores St    2  San Francisco          CA 94119     USA  Bready Shop
# 332 Hill St       3  San Francisco  California 94114     USA  Super River
# 3995 23rd St      4  San Francisco          CA 94114     USA   Ben's Shop
# 1056 Sanchez St   5  San Francisco        California     USA      Sanchez
#
#                  Employees
# Address
# 3666 21st St             8
# 735 Dolores St          15
# 332 Hill St             25
# 3995 23rd St            10
# 1056 Sanchez St         12

# %%
df7.loc["735 Dolores St":"332 Hill St","ID":"Country"]
# Out:
#                 ID           City             State Country
# Address
# 735 Dolores St   2  San Francisco          CA 94119     USA
# 332 Hill St      3  San Francisco  California 94114     USA
